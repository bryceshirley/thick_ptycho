# %% [markdown]
# # Thick Sample Ptychography Forward Model Tutorial 3D
#
# This tutorial demonstrates how to use `thickptypy` to set up and solve a 3D forward problem with multiple probes, both iteratively and as a full system.

# %% [markdown]
# The forward model solves the paraxial equation:
#
# \begin{equation}
# \frac{\partial u}{\partial z} = a (\frac{\partial^2 u}{\partial x^2} + \frac{\partial^2 u}{\partial y^2})  + C(x, y, z) u,
# \end{equation}
# where
# \begin{equation}
# a := \frac{1}{2ik} \qquad \text{and} \qquad C(x,y, z) := \frac{k}{2i} \left(n^2(x,y, z) - 1\right)
# \end{equation}
#
#
# **$n$ defines the refractive index of the volume.**

# %% [markdown]
# ### 1. Import Libraries: Sample Space and Forward Model

# %%
from thickptypy.sample_space.sample_space import SampleSpace
from thickptypy.forward_model.solver import ForwardModel

# %% [markdown]
# ### 2. Set Simulation Parameters
#
# Choose boundary conditions, probe type, and define the spatial domain and discretization.

# %%
bc_type = "impedance"               # Boundary condition type 
probe_type = "disk"                 # Airy disk probe
wave_number = 1e4  # Wave number

# Continuous space limits (micrometers)
xlims = [0, 1000]                    # X limits in micrometers
ylims = [0, 1000]                    # Y limits in micrometers
zlims = [0, 20]

# Continuous space parameters
continuous_dimensions = [
    xlims, 
    ylims, 
    zlims
    ]                     # Continuous dimensions in micrometers

# Discrete space parameters
propagation_slices = 20              # Number of z slices
probe_dimensions = [32, 32]         # Detector shape can be different from discrete_dimensions
probe_diameter = 20                 # Diameter if using initial condition "disk"
scan_points = 30                     # Single probe
step_size = 4                     # Step size in pixels


# Discrete space limits (pixels)
min_nx = int(scan_points * step_size + probe_dimensions[0])
min_ny = int(scan_points * step_size + probe_dimensions[1])
print(f"Pixels for compatibility with Diamond thin-sample simulation:")
print(f"nx = {min_nx} and ny = {min_ny}")
print(f"(These are also the minimum values for the discrete space limits)")

nx, ny = 50, 50          # Number of pixels in x and y directions
if nx < min_nx:
    nx = min_nx
if ny < min_ny:
    ny = min_ny
discrete_dimensions = [
    nx, 
    ny, 
    propagation_slices
    ]
# Out:
# Pixels for compatibility with Diamond thin-sample simulation:
# nx = 152 and ny = 152
# (These are also the minimum values for the discrete space limits)

# %% [markdown]
# ### 3. Create Sample Space
#
# Initialize the sample space. The sample space dimensions are defined here as well
# as it's discritization in pixels. The subdimensions

# %%
sample_space = SampleSpace(
    continuous_dimensions, # sample space dimensions in nanometers (x, z) or (x, y, z)
    discrete_dimensions,   # sample space dimensions in pixels (nx, nz) or (nx, ny, nz)
    probe_dimensions,        # shape of the detector in pixels - subset of (nx) or (nx, ny)
    scan_points,           # number of ptychography scan points or sqrt(scan_points) for square scan
    step_size,
    bc_type,               # boundary condition type (impedance, dirichlet, neumann)
    probe_type,
    wave_number,            # wavenumber in 1/nm
    probe_diameter=probe_diameter
)
sample_space.summarize_sample_space()
# Out:
# Summary of the scan (continuous):
#     Sample space x: 1000 um
#     Sample space y: 1000 um
#     Sample space z: 20 um
#     Probe Diameter: 132.45 um
#     Number of scan points: 900
#     Max Overlap: 106.13 um

# %% [markdown]
# ### 4. Add Objects and Visualize Sample Space
#
# Add cubiods, prisms or cylinders with specified refractive indices to the sample space.
#
# Or load in your own sample space.

# %%
# Add objects to the sample space and generate it
# Refractive index: 1 + e-4 + e-6i
delta = 1e-4
beta = 1e-6j
refractive_index_pertubation1 = delta + beta
refractive_index_pertubation2 = 0.99*delta + beta
guassian_blur = 0.0 # removes sharp edges in the refractive index perturbation
sample_space.add_object('prism', refractive_index_pertubation1, side_length=0.3*xlims[1],
                         centre=(xlims[1]*0.65, xlims[1]*0.65, zlims[1]*0.5),
                         depth=zlims[1]*0.8,guassian_blur=guassian_blur)
sample_space.add_object('cuboid', refractive_index_pertubation2, side_length=0.2*xlims[1],
                        centre=(xlims[1]*0.4, xlims[1]*0.4, zlims[1]*0.5),
                        depth=zlims[1]*0.8,guassian_blur=guassian_blur)

sample_space.generate_sample_space()

# %%
# # Alternatively, load in your own sample space
# filepath = "./data/simulated_spheres_128.npy"
# sample_space.load_sample_space(filepath)

# %%
# Import Visualisation module
from thickptypy.utils.visualisations import Visualisation

visualisation = Visualisation(sample_space=sample_space)

# Visualise the Sample Space
visualisation.plot(solution=sample_space.n_true, slider=True, title=" (Sample Space Refractive Index)")
# Out:
# interactive(children=(IntSlider(value=0, description='slice', max=19), Output()), _dom_classes=('widget-intera…

# %% [markdown]
# ### 5. Solve the Forward Model
#
# Solve the forward problem both iteratively and as a full system for sub-samples
# and the full sample.

# %%
# Solve Full Space
thin_sample = True
forward_model_iterative_thin = ForwardModel(sample_space, thin_sample=thin_sample)

# Iterative solution
print("Solving iteratively for thin sample...")
solution_iterative_thin = forward_model_iterative_thin.solve(verbose=True)
# Out:
# Solving iteratively for thin sample...
# Time to solve scan 1/900: 0.11685466766357422 seconds
# Time to solve scan 2/900: 0.07186675071716309 seconds
# Time to solve scan 3/900: 0.15344786643981934 seconds
# Time to solve scan 4/900: 0.0732431411743164 seconds
# Time to solve scan 5/900: 0.06809210777282715 seconds
# Time to solve scan 6/900: 0.0717008113861084 seconds
# Time to solve scan 7/900: 0.06426119804382324 seconds
# Time to solve scan 8/900: 0.07151937484741211 seconds
# Time to solve scan 9/900: 0.06788206100463867 seconds
# Time to solve scan 10/900: 0.06557273864746094 seconds
# Time to solve scan 11/900: 0.06930875778198242 seconds
# Time to solve scan 12/900: 0.07132840156555176 seconds
# Time to solve scan 13/900: 0.06511998176574707 seconds
# Time to solve scan 14/900: 0.06389331817626953 seconds
# Time to solve scan 15/900: 0.06162428855895996 seconds
# Time to solve scan 16/900: 0.06987690925598145 seconds
# Time to solve scan 17/900: 0.11097979545593262 seconds
# Time to solve scan 18/900: 0.06485891342163086 seconds
# Time to solve scan 19/900: 0.06449460983276367 seconds
# Time to solve scan 20/900: 0.06419539451599121 seconds
# Time to solve scan 21/900: 0.06474113464355469 seconds
# Time to solve scan 22/900: 0.06684350967407227 seconds
# Time to solve scan 23/900: 0.06991338729858398 seconds
# Time to solve scan 24/900: 0.06917858123779297 seconds
# Time to solve scan 25/900: 0.06976509094238281 seconds
# Time to solve scan 26/900: 0.07074546813964844 seconds
# Time to solve scan 27/900: 0.0825338363647461 seconds
# Time to solve scan 28/900: 0.0709531307220459 seconds
# Time to solve scan 29/900: 0.07027316093444824 seconds
# Time to solve scan 30/900: 0.07059979438781738 seconds
# Time to solve scan 31/900: 0.0702064037322998 seconds
# Time to solve scan 32/900: 0.07288837432861328 seconds
# Time to solve scan 33/900: 0.10987043380737305 seconds
# Time to solve scan 34/900: 0.06922173500061035 seconds
# Time to solve scan 35/900: 0.06672358512878418 seconds
# Time to solve scan 36/900: 0.06785702705383301 seconds
# Time to solve scan 37/900: 0.06748270988464355 seconds
# Time to solve scan 38/900: 0.06043195724487305 seconds
# Time to solve scan 39/900: 0.0715031623840332 seconds
# Time to solve scan 40/900: 0.06522202491760254 seconds
# Time to solve scan 41/900: 0.06300806999206543 seconds
# Time to solve scan 42/900: 0.06993627548217773 seconds
# Time to solve scan 43/900: 0.06575918197631836 seconds
# Time to solve scan 44/900: 0.08218622207641602 seconds
# Time to solve scan 45/900: 0.06961536407470703 seconds
# Time to solve scan 46/900: 0.07210922241210938 seconds
# Time to solve scan 47/900: 0.06700873374938965 seconds
# Time to solve scan 48/900: 0.06577134132385254 seconds
# Time to solve scan 49/900: 0.10478425025939941 seconds
# Time to solve scan 50/900: 0.0648949146270752 seconds
# Time to solve scan 51/900: 0.06433606147766113 seconds
# Time to solve scan 52/900: 0.06463479995727539 seconds
# Time to solve scan 53/900: 0.0738229751586914 seconds
# Time to solve scan 54/900: 0.06290745735168457 seconds
# Time to solve scan 55/900: 0.0688936710357666 seconds
# Time to solve scan 56/900: 0.08456659317016602 seconds
# Time to solve scan 57/900: 0.09399223327636719 seconds
# Time to solve scan 58/900: 0.07979846000671387 seconds
# Time to solve scan 59/900: 0.07213044166564941 seconds
# Time to solve scan 60/900: 0.07638168334960938 seconds
# Time to solve scan 61/900: 0.06434440612792969 seconds
# Time to solve scan 62/900: 0.06372451782226562 seconds
# Time to solve scan 63/900: 0.07120752334594727 seconds
# Time to solve scan 64/900: 0.11845946311950684 seconds
# Time to solve scan 65/900: 0.06601667404174805 seconds
# Time to solve scan 66/900: 0.06473159790039062 seconds
# Time to solve scan 67/900: 0.0650782585144043 seconds
# Time to solve scan 68/900: 0.06760764122009277 seconds
# Time to solve scan 69/900: 0.07364296913146973 seconds
# Time to solve scan 70/900: 0.06358551979064941 seconds
# Time to solve scan 71/900: 0.06449747085571289 seconds
# Time to solve scan 72/900: 0.06836104393005371 seconds
# Time to solve scan 73/900: 0.06903076171875 seconds
# Time to solve scan 74/900: 0.06717729568481445 seconds
# Time to solve scan 75/900: 0.06607913970947266 seconds
# Time to solve scan 76/900: 0.06655120849609375 seconds
# Time to solve scan 77/900: 0.06617045402526855 seconds
# Time to solve scan 78/900: 0.0662698745727539 seconds
# Time to solve scan 79/900: 0.06423687934875488 seconds
# Time to solve scan 80/900: 0.10094308853149414 seconds
# Time to solve scan 81/900: 0.06127429008483887 seconds
# Time to solve scan 82/900: 0.09726071357727051 seconds
# Time to solve scan 83/900: 0.08287334442138672 seconds
# Time to solve scan 84/900: 0.07638263702392578 seconds
# Time to solve scan 85/900: 0.08533453941345215 seconds
# Time to solve scan 86/900: 0.08138895034790039 seconds
# Time to solve scan 87/900: 0.07108783721923828 seconds
# Time to solve scan 88/900: 0.07322001457214355 seconds
# Time to solve scan 89/900: 0.07345247268676758 seconds
# Time to solve scan 90/900: 0.0684812068939209 seconds
# Time to solve scan 91/900: 0.06749129295349121 seconds
# Time to solve scan 92/900: 0.07109618186950684 seconds
# Time to solve scan 93/900: 0.06293153762817383 seconds
# Time to solve scan 94/900: 0.06627225875854492 seconds
# Time to solve scan 95/900: 0.06623649597167969 seconds
# Time to solve scan 96/900: 0.10139989852905273 seconds
# Time to solve scan 97/900: 0.06591057777404785 seconds
# Time to solve scan 98/900: 0.0662987232208252 seconds
# Time to solve scan 99/900: 0.06693720817565918 seconds
# Time to solve scan 100/900: 0.07166028022766113 seconds
# Time to solve scan 101/900: 0.07030940055847168 seconds
# Time to solve scan 102/900: 0.06066584587097168 seconds
# Time to solve scan 103/900: 0.06273698806762695 seconds
# Time to solve scan 104/900: 0.06369185447692871 seconds
# Time to solve scan 105/900: 0.06549572944641113 seconds
# Time to solve scan 106/900: 0.06192660331726074 seconds
# Time to solve scan 107/900: 0.05952882766723633 seconds
# Time to solve scan 108/900: 0.06596827507019043 seconds
# Time to solve scan 109/900: 0.06840205192565918 seconds
# Time to solve scan 110/900: 0.0642080307006836 seconds
# Time to solve scan 111/900: 0.06824755668640137 seconds
# Time to solve scan 112/900: 0.11095952987670898 seconds
# Time to solve scan 113/900: 0.0743246078491211 seconds
# Time to solve scan 114/900: 0.08294010162353516 seconds
# Time to solve scan 115/900: 0.08514904975891113 seconds
# Time to solve scan 116/900: 0.08040523529052734 seconds
# Time to solve scan 117/900: 0.06458926200866699 seconds
# Time to solve scan 118/900: 0.06583142280578613 seconds
# Time to solve scan 119/900: 0.06421494483947754 seconds
# Time to solve scan 120/900: 0.07083964347839355 seconds
# Time to solve scan 121/900: 0.07028508186340332 seconds
# Time to solve scan 122/900: 0.07140779495239258 seconds
# Time to solve scan 123/900: 0.0689079761505127 seconds
# Time to solve scan 124/900: 0.06331086158752441 seconds
# Time to solve scan 125/900: 0.05985283851623535 seconds
# Time to solve scan 126/900: 0.06163191795349121 seconds
# Time to solve scan 127/900: 0.06984090805053711 seconds
# Time to solve scan 128/900: 0.1091299057006836 seconds
# Time to solve scan 129/900: 0.0694124698638916 seconds
# Time to solve scan 130/900: 0.06572461128234863 seconds
# Time to solve scan 131/900: 0.06971359252929688 seconds
# Time to solve scan 132/900: 0.059784889221191406 seconds
# Time to solve scan 133/900: 0.06362533569335938 seconds
# Time to solve scan 134/900: 0.07048726081848145 seconds
# Time to solve scan 135/900: 0.06536436080932617 seconds
# Time to solve scan 136/900: 0.07001471519470215 seconds
# Time to solve scan 137/900: 0.06472945213317871 seconds
# Time to solve scan 138/900: 0.06602787971496582 seconds
# Time to solve scan 139/900: 0.06735658645629883 seconds
# Time to solve scan 140/900: 0.0666050910949707 seconds
# Time to solve scan 141/900: 0.06421589851379395 seconds
# Time to solve scan 142/900: 0.0702974796295166 seconds
# Time to solve scan 143/900: 0.0709538459777832 seconds
# Time to solve scan 144/900: 0.12584924697875977 seconds
# Time to solve scan 145/900: 0.08081698417663574 seconds
# Time to solve scan 146/900: 0.08397388458251953 seconds
# Time to solve scan 147/900: 0.07139158248901367 seconds
# Time to solve scan 148/900: 0.0723276138305664 seconds
# Time to solve scan 149/900: 0.07171392440795898 seconds
# Time to solve scan 150/900: 0.06886148452758789 seconds
# Time to solve scan 151/900: 0.07050466537475586 seconds
# Time to solve scan 152/900: 0.06534314155578613 seconds
# Time to solve scan 153/900: 0.061441659927368164 seconds
# Time to solve scan 154/900: 0.06430292129516602 seconds
# Time to solve scan 155/900: 0.0651702880859375 seconds
# Time to solve scan 156/900: 0.06381773948669434 seconds
# Time to solve scan 157/900: 0.06716084480285645 seconds
# Time to solve scan 158/900: 0.06713485717773438 seconds
# Time to solve scan 159/900: 0.06832647323608398 seconds
# Time to solve scan 160/900: 0.09877300262451172 seconds
# Time to solve scan 161/900: 0.05919337272644043 seconds
# Time to solve scan 162/900: 0.07321882247924805 seconds
# Time to solve scan 163/900: 0.06681704521179199 seconds
# Time to solve scan 164/900: 0.07044363021850586 seconds
# Time to solve scan 165/900: 0.06150341033935547 seconds
# Time to solve scan 166/900: 0.0619509220123291 seconds
# Time to solve scan 167/900: 0.07412409782409668 seconds
# Time to solve scan 168/900: 0.06838226318359375 seconds
# Time to solve scan 169/900: 0.07067441940307617 seconds
# Time to solve scan 170/900: 0.06489276885986328 seconds
# Time to solve scan 171/900: 0.07102775573730469 seconds
# Time to solve scan 172/900: 0.07409286499023438 seconds
# Time to solve scan 173/900: 0.06718993186950684 seconds
# Time to solve scan 174/900: 0.06872344017028809 seconds
# Time to solve scan 175/900: 0.07412457466125488 seconds
# Time to solve scan 176/900: 0.12175965309143066 seconds
# Time to solve scan 177/900: 0.06292366981506348 seconds
# Time to solve scan 178/900: 0.06877851486206055 seconds
# Time to solve scan 179/900: 0.0691683292388916 seconds
# Time to solve scan 180/900: 0.07675027847290039 seconds
# Time to solve scan 181/900: 0.06978988647460938 seconds
# Time to solve scan 182/900: 0.0678858757019043 seconds
# Time to solve scan 183/900: 0.06777215003967285 seconds
# Time to solve scan 184/900: 0.06455111503601074 seconds
# Time to solve scan 185/900: 0.07908511161804199 seconds
# Time to solve scan 186/900: 0.07789897918701172 seconds
# Time to solve scan 187/900: 0.0767524242401123 seconds
# Time to solve scan 188/900: 0.06933712959289551 seconds
# Time to solve scan 189/900: 0.07458138465881348 seconds
# Time to solve scan 190/900: 0.11852192878723145 seconds
# Time to solve scan 191/900: 0.07439327239990234 seconds
# Time to solve scan 192/900: 0.0737910270690918 seconds
# Time to solve scan 193/900: 0.0766456127166748 seconds
# Time to solve scan 194/900: 0.07800602912902832 seconds
# Time to solve scan 195/900: 0.07422471046447754 seconds
# Time to solve scan 196/900: 0.0811622142791748 seconds
# Time to solve scan 197/900: 0.07491111755371094 seconds
# Time to solve scan 198/900: 0.08687663078308105 seconds
# Time to solve scan 199/900: 0.09833288192749023 seconds
# Time to solve scan 200/900: 0.07310366630554199 seconds
# Time to solve scan 201/900: 0.07012486457824707 seconds
# Time to solve scan 202/900: 0.07154178619384766 seconds
# Time to solve scan 203/900: 0.09388184547424316 seconds
# Time to solve scan 204/900: 0.08541631698608398 seconds
# Time to solve scan 205/900: 0.06685042381286621 seconds
# Time to solve scan 206/900: 0.11034631729125977 seconds
# Time to solve scan 207/900: 0.06902837753295898 seconds
# Time to solve scan 208/900: 0.07636427879333496 seconds
# Time to solve scan 209/900: 0.06344842910766602 seconds
# Time to solve scan 210/900: 0.06529474258422852 seconds
# Time to solve scan 211/900: 0.07210707664489746 seconds
# Time to solve scan 212/900: 0.07244443893432617 seconds
# Time to solve scan 213/900: 0.07424139976501465 seconds
# Time to solve scan 214/900: 0.07165670394897461 seconds
# Time to solve scan 215/900: 0.06917309761047363 seconds
# Time to solve scan 216/900: 0.07393741607666016 seconds
# Time to solve scan 217/900: 0.07027554512023926 seconds
# Time to solve scan 218/900: 0.07004189491271973 seconds
# Time to solve scan 219/900: 0.07786774635314941 seconds
# Time to solve scan 220/900: 0.08044290542602539 seconds
# Time to solve scan 221/900: 0.07534074783325195 seconds
# Time to solve scan 222/900: 0.13164710998535156 seconds
# Time to solve scan 223/900: 0.07845759391784668 seconds
# Time to solve scan 224/900: 0.07293367385864258 seconds
# Time to solve scan 225/900: 0.07584214210510254 seconds
# Time to solve scan 226/900: 0.07922983169555664 seconds
# Time to solve scan 227/900: 0.07894659042358398 seconds
# Time to solve scan 228/900: 0.07803463935852051 seconds
# Time to solve scan 229/900: 0.07300138473510742 seconds
# Time to solve scan 230/900: 0.07769083976745605 seconds
# Time to solve scan 231/900: 0.07616019248962402 seconds
# Time to solve scan 232/900: 0.07855343818664551 seconds
# Time to solve scan 233/900: 0.07103490829467773 seconds
# Time to solve scan 234/900: 0.0696256160736084 seconds
# Time to solve scan 235/900: 0.06769251823425293 seconds
# Time to solve scan 236/900: 0.07172679901123047 seconds
# Time to solve scan 237/900: 0.07018184661865234 seconds
# Time to solve scan 238/900: 0.11775326728820801 seconds
# Time to solve scan 239/900: 0.07552123069763184 seconds
# Time to solve scan 240/900: 0.07347917556762695 seconds
# Time to solve scan 241/900: 0.06784248352050781 seconds
# Time to solve scan 242/900: 0.06982278823852539 seconds
# Time to solve scan 243/900: 0.06026935577392578 seconds
# Time to solve scan 244/900: 0.0709538459777832 seconds
# Time to solve scan 245/900: 0.06958293914794922 seconds
# Time to solve scan 246/900: 0.07593584060668945 seconds
# Time to solve scan 247/900: 0.0737600326538086 seconds
# Time to solve scan 248/900: 0.07621884346008301 seconds
# Time to solve scan 249/900: 0.07768487930297852 seconds
# Time to solve scan 250/900: 0.0721595287322998 seconds
# Time to solve scan 251/900: 0.06343364715576172 seconds
# Time to solve scan 252/900: 0.06535673141479492 seconds
# Time to solve scan 253/900: 0.06736159324645996 seconds
# Time to solve scan 254/900: 0.10432863235473633 seconds
# Time to solve scan 255/900: 0.0653831958770752 seconds
# Time to solve scan 256/900: 0.07256126403808594 seconds
# Time to solve scan 257/900: 0.06791210174560547 seconds
# Time to solve scan 258/900: 0.06545495986938477 seconds
# Time to solve scan 259/900: 0.07080626487731934 seconds
# Time to solve scan 260/900: 0.0728154182434082 seconds
# Time to solve scan 261/900: 0.07588934898376465 seconds
# Time to solve scan 262/900: 0.06662249565124512 seconds
# Time to solve scan 263/900: 0.06371402740478516 seconds
# Time to solve scan 264/900: 0.06128120422363281 seconds
# Time to solve scan 265/900: 0.06912517547607422 seconds
# Time to solve scan 266/900: 0.06870460510253906 seconds
# Time to solve scan 267/900: 0.07306528091430664 seconds
# Time to solve scan 268/900: 0.07036399841308594 seconds
# Time to solve scan 269/900: 0.060494422912597656 seconds
# Time to solve scan 270/900: 0.10564899444580078 seconds
# Time to solve scan 271/900: 0.06665515899658203 seconds
# Time to solve scan 272/900: 0.06085538864135742 seconds
# Time to solve scan 273/900: 0.06389904022216797 seconds
# Time to solve scan 274/900: 0.06720638275146484 seconds
# Time to solve scan 275/900: 0.07465624809265137 seconds
# Time to solve scan 276/900: 0.06981444358825684 seconds
# Time to solve scan 277/900: 0.0805521011352539 seconds
# Time to solve scan 278/900: 0.07430768013000488 seconds
# Time to solve scan 279/900: 0.06591415405273438 seconds
# Time to solve scan 280/900: 0.06287884712219238 seconds
# Time to solve scan 281/900: 0.062232017517089844 seconds
# Time to solve scan 282/900: 0.06371903419494629 seconds
# Time to solve scan 283/900: 0.0648493766784668 seconds
# Time to solve scan 284/900: 0.07372856140136719 seconds
# Time to solve scan 285/900: 0.06595253944396973 seconds
# Time to solve scan 286/900: 0.10345077514648438 seconds
# Time to solve scan 287/900: 0.06531977653503418 seconds
# Time to solve scan 288/900: 0.06532645225524902 seconds
# Time to solve scan 289/900: 0.0668797492980957 seconds
# Time to solve scan 290/900: 0.07517838478088379 seconds
# Time to solve scan 291/900: 0.07835865020751953 seconds
# Time to solve scan 292/900: 0.07918739318847656 seconds
# Time to solve scan 293/900: 0.07074284553527832 seconds
# Time to solve scan 294/900: 0.06816244125366211 seconds
# Time to solve scan 295/900: 0.06487226486206055 seconds
# Time to solve scan 296/900: 0.06964993476867676 seconds
# Time to solve scan 297/900: 0.06035780906677246 seconds
# Time to solve scan 298/900: 0.058519601821899414 seconds
# Time to solve scan 299/900: 0.06595444679260254 seconds
# Time to solve scan 300/900: 0.06070852279663086 seconds
# Time to solve scan 301/900: 0.06957650184631348 seconds
# Time to solve scan 302/900: 0.10290384292602539 seconds
# Time to solve scan 303/900: 0.06816363334655762 seconds
# Time to solve scan 304/900: 0.06688141822814941 seconds
# Time to solve scan 305/900: 0.06770467758178711 seconds
# Time to solve scan 306/900: 0.07916140556335449 seconds
# Time to solve scan 307/900: 0.07076692581176758 seconds
# Time to solve scan 308/900: 0.059952735900878906 seconds
# Time to solve scan 309/900: 0.0629262924194336 seconds
# Time to solve scan 310/900: 0.06673979759216309 seconds
# Time to solve scan 311/900: 0.061025142669677734 seconds
# Time to solve scan 312/900: 0.05935788154602051 seconds
# Time to solve scan 313/900: 0.07079935073852539 seconds
# Time to solve scan 314/900: 0.06572103500366211 seconds
# Time to solve scan 315/900: 0.06696867942810059 seconds
# Time to solve scan 316/900: 0.0688779354095459 seconds
# Time to solve scan 317/900: 0.0627131462097168 seconds
# Time to solve scan 318/900: 0.09792637825012207 seconds
# Time to solve scan 319/900: 0.06752657890319824 seconds
# Time to solve scan 320/900: 0.07135868072509766 seconds
# Time to solve scan 321/900: 0.08284902572631836 seconds
# Time to solve scan 322/900: 0.07195043563842773 seconds
# Time to solve scan 323/900: 0.06676554679870605 seconds
# Time to solve scan 324/900: 0.06179094314575195 seconds
# Time to solve scan 325/900: 0.06837034225463867 seconds
# Time to solve scan 326/900: 0.06215834617614746 seconds
# Time to solve scan 327/900: 0.0660252571105957 seconds
# Time to solve scan 328/900: 0.06678438186645508 seconds
# Time to solve scan 329/900: 0.06349468231201172 seconds
# Time to solve scan 330/900: 0.06591510772705078 seconds
# Time to solve scan 331/900: 0.07047581672668457 seconds
# Time to solve scan 332/900: 0.07005572319030762 seconds
# Time to solve scan 333/900: 0.10479569435119629 seconds
# Time to solve scan 334/900: 0.07263302803039551 seconds
# Time to solve scan 335/900: 0.07610082626342773 seconds
# Time to solve scan 336/900: 0.06719160079956055 seconds
# Time to solve scan 337/900: 0.06776809692382812 seconds
# Time to solve scan 338/900: 0.06828570365905762 seconds
# Time to solve scan 339/900: 0.0648043155670166 seconds
# Time to solve scan 340/900: 0.07089734077453613 seconds
# Time to solve scan 341/900: 0.06647920608520508 seconds
# Time to solve scan 342/900: 0.06323099136352539 seconds
# Time to solve scan 343/900: 0.0644683837890625 seconds
# Time to solve scan 344/900: 0.0660398006439209 seconds
# Time to solve scan 345/900: 0.06611013412475586 seconds
# Time to solve scan 346/900: 0.06656289100646973 seconds
# Time to solve scan 347/900: 0.06417226791381836 seconds
# Time to solve scan 348/900: 0.06922292709350586 seconds
# Time to solve scan 349/900: 0.10251545906066895 seconds
# Time to solve scan 350/900: 0.07617783546447754 seconds
# Time to solve scan 351/900: 0.07685375213623047 seconds
# Time to solve scan 352/900: 0.07419919967651367 seconds
# Time to solve scan 353/900: 0.06553506851196289 seconds
# Time to solve scan 354/900: 0.07346415519714355 seconds
# Time to solve scan 355/900: 0.0769195556640625 seconds
# Time to solve scan 356/900: 0.06461429595947266 seconds
# Time to solve scan 357/900: 0.06819581985473633 seconds
# Time to solve scan 358/900: 0.06993246078491211 seconds
# Time to solve scan 359/900: 0.07045364379882812 seconds
# Time to solve scan 360/900: 0.07244563102722168 seconds
# Time to solve scan 361/900: 0.06884169578552246 seconds
# Time to solve scan 362/900: 0.06737923622131348 seconds
# Time to solve scan 363/900: 0.0644228458404541 seconds
# Time to solve scan 364/900: 0.07648396492004395 seconds
# Time to solve scan 365/900: 0.09826803207397461 seconds
# Time to solve scan 366/900: 0.06679439544677734 seconds
# Time to solve scan 367/900: 0.06849455833435059 seconds
# Time to solve scan 368/900: 0.06816959381103516 seconds
# Time to solve scan 369/900: 0.06212496757507324 seconds
# Time to solve scan 370/900: 0.07278084754943848 seconds
# Time to solve scan 371/900: 0.07101225852966309 seconds
# Time to solve scan 372/900: 0.06466460227966309 seconds
# Time to solve scan 373/900: 0.06911325454711914 seconds
# Time to solve scan 374/900: 0.0702521800994873 seconds
# Time to solve scan 375/900: 0.06822347640991211 seconds
# Time to solve scan 376/900: 0.0706474781036377 seconds
# Time to solve scan 377/900: 0.07454681396484375 seconds
# Time to solve scan 378/900: 0.062323570251464844 seconds
# Time to solve scan 379/900: 0.0733649730682373 seconds
# Time to solve scan 380/900: 0.07307720184326172 seconds
# Time to solve scan 381/900: 0.11727523803710938 seconds
# Time to solve scan 382/900: 0.07383108139038086 seconds
# Time to solve scan 383/900: 0.06783437728881836 seconds
# Time to solve scan 384/900: 0.06540346145629883 seconds
# Time to solve scan 385/900: 0.0682382583618164 seconds
# Time to solve scan 386/900: 0.07528424263000488 seconds
# Time to solve scan 387/900: 0.07010817527770996 seconds
# Time to solve scan 388/900: 0.07396268844604492 seconds
# Time to solve scan 389/900: 0.07108259201049805 seconds
# Time to solve scan 390/900: 0.0886845588684082 seconds
# Time to solve scan 391/900: 0.09011006355285645 seconds
# Time to solve scan 392/900: 0.07298731803894043 seconds
# Time to solve scan 393/900: 0.06935405731201172 seconds
# Time to solve scan 394/900: 0.0773477554321289 seconds
# Time to solve scan 395/900: 0.07385373115539551 seconds
# Time to solve scan 396/900: 0.06932210922241211 seconds
# Time to solve scan 397/900: 0.10867547988891602 seconds
# Time to solve scan 398/900: 0.0710148811340332 seconds
# Time to solve scan 399/900: 0.07558703422546387 seconds
# Time to solve scan 400/900: 0.06605386734008789 seconds
# Time to solve scan 401/900: 0.07107305526733398 seconds
# Time to solve scan 402/900: 0.08795571327209473 seconds
# Time to solve scan 403/900: 0.08362054824829102 seconds
# Time to solve scan 404/900: 0.06688880920410156 seconds
# Time to solve scan 405/900: 0.06011056900024414 seconds
# Time to solve scan 406/900: 0.07314825057983398 seconds
# Time to solve scan 407/900: 0.07289481163024902 seconds
# Time to solve scan 408/900: 0.06842517852783203 seconds
# Time to solve scan 409/900: 0.07531523704528809 seconds
# Time to solve scan 410/900: 0.06770110130310059 seconds
# Time to solve scan 411/900: 0.06858134269714355 seconds
# Time to solve scan 412/900: 0.07398581504821777 seconds
# Time to solve scan 413/900: 0.1074223518371582 seconds
# Time to solve scan 414/900: 0.0745084285736084 seconds
# Time to solve scan 415/900: 0.06823086738586426 seconds
# Time to solve scan 416/900: 0.07131123542785645 seconds
# Time to solve scan 417/900: 0.07573556900024414 seconds
# Time to solve scan 418/900: 0.06509876251220703 seconds
# Time to solve scan 419/900: 0.0666191577911377 seconds
# Time to solve scan 420/900: 0.06743502616882324 seconds
# Time to solve scan 421/900: 0.06645965576171875 seconds
# Time to solve scan 422/900: 0.07542800903320312 seconds
# Time to solve scan 423/900: 0.0661623477935791 seconds
# Time to solve scan 424/900: 0.0674135684967041 seconds
# Time to solve scan 425/900: 0.06633305549621582 seconds
# Time to solve scan 426/900: 0.0636138916015625 seconds
# Time to solve scan 427/900: 0.06460189819335938 seconds
# Time to solve scan 428/900: 0.06635475158691406 seconds
# Time to solve scan 429/900: 0.11099052429199219 seconds
# Time to solve scan 430/900: 0.06677103042602539 seconds
# Time to solve scan 431/900: 0.07059431076049805 seconds
# Time to solve scan 432/900: 0.06628751754760742 seconds
# Time to solve scan 433/900: 0.07155132293701172 seconds
# Time to solve scan 434/900: 0.06364750862121582 seconds
# Time to solve scan 435/900: 0.06280183792114258 seconds
# Time to solve scan 436/900: 0.06740880012512207 seconds
# Time to solve scan 437/900: 0.06570005416870117 seconds
# Time to solve scan 438/900: 0.07873225212097168 seconds
# Time to solve scan 439/900: 0.06624269485473633 seconds
# Time to solve scan 440/900: 0.07576298713684082 seconds
# Time to solve scan 441/900: 0.08047151565551758 seconds
# Time to solve scan 442/900: 0.06751585006713867 seconds
# Time to solve scan 443/900: 0.06838202476501465 seconds
# Time to solve scan 444/900: 0.06994915008544922 seconds
# Time to solve scan 445/900: 0.10824084281921387 seconds
# Time to solve scan 446/900: 0.07498812675476074 seconds
# Time to solve scan 447/900: 0.07392430305480957 seconds
# Time to solve scan 448/900: 0.07060647010803223 seconds
# Time to solve scan 449/900: 0.06366181373596191 seconds
# Time to solve scan 450/900: 0.06595897674560547 seconds
# Time to solve scan 451/900: 0.06979727745056152 seconds
# Time to solve scan 452/900: 0.06896018981933594 seconds
# Time to solve scan 453/900: 0.07482504844665527 seconds
# Time to solve scan 454/900: 0.0825653076171875 seconds
# Time to solve scan 455/900: 0.0694892406463623 seconds
# Time to solve scan 456/900: 0.0717921257019043 seconds
# Time to solve scan 457/900: 0.07334399223327637 seconds
# Time to solve scan 458/900: 0.06459164619445801 seconds
# Time to solve scan 459/900: 0.06659197807312012 seconds
# Time to solve scan 460/900: 0.06708073616027832 seconds
# Time to solve scan 461/900: 0.1077566146850586 seconds
# Time to solve scan 462/900: 0.061881303787231445 seconds
# Time to solve scan 463/900: 0.06451272964477539 seconds
# Time to solve scan 464/900: 0.07955503463745117 seconds
# Time to solve scan 465/900: 0.07971405982971191 seconds
# Time to solve scan 466/900: 0.07276177406311035 seconds
# Time to solve scan 467/900: 0.07508969306945801 seconds
# Time to solve scan 468/900: 0.0783998966217041 seconds
# Time to solve scan 469/900: 0.08236432075500488 seconds
# Time to solve scan 470/900: 0.07252979278564453 seconds
# Time to solve scan 471/900: 0.08152365684509277 seconds
# Time to solve scan 472/900: 0.07106733322143555 seconds
# Time to solve scan 473/900: 0.07775139808654785 seconds
# Time to solve scan 474/900: 0.06812262535095215 seconds
# Time to solve scan 475/900: 0.07018613815307617 seconds
# Time to solve scan 476/900: 0.1180565357208252 seconds
# Time to solve scan 477/900: 0.07043814659118652 seconds
# Time to solve scan 478/900: 0.0668179988861084 seconds
# Time to solve scan 479/900: 0.06889557838439941 seconds
# Time to solve scan 480/900: 0.06782913208007812 seconds
# Time to solve scan 481/900: 0.06708121299743652 seconds
# Time to solve scan 482/900: 0.07292675971984863 seconds
# Time to solve scan 483/900: 0.07439279556274414 seconds
# Time to solve scan 484/900: 0.07372403144836426 seconds
# Time to solve scan 485/900: 0.07597160339355469 seconds
# Time to solve scan 486/900: 0.07352256774902344 seconds
# Time to solve scan 487/900: 0.06629395484924316 seconds
# Time to solve scan 488/900: 0.07167339324951172 seconds
# Time to solve scan 489/900: 0.08380246162414551 seconds
# Time to solve scan 490/900: 0.07052850723266602 seconds
# Time to solve scan 491/900: 0.06594252586364746 seconds
# Time to solve scan 492/900: 0.12823081016540527 seconds
# Time to solve scan 493/900: 0.07064080238342285 seconds
# Time to solve scan 494/900: 0.07941532135009766 seconds
# Time to solve scan 495/900: 0.08637762069702148 seconds
# Time to solve scan 496/900: 0.07570290565490723 seconds
# Time to solve scan 497/900: 0.08109378814697266 seconds
# Time to solve scan 498/900: 0.07382631301879883 seconds
# Time to solve scan 499/900: 0.07151651382446289 seconds
# Time to solve scan 500/900: 0.07227063179016113 seconds
# Time to solve scan 501/900: 0.07219672203063965 seconds
# Time to solve scan 502/900: 0.0808725357055664 seconds
# Time to solve scan 503/900: 0.0811305046081543 seconds
# Time to solve scan 504/900: 0.07283258438110352 seconds
# Time to solve scan 505/900: 0.07320308685302734 seconds
# Time to solve scan 506/900: 0.07706832885742188 seconds
# Time to solve scan 507/900: 0.07794761657714844 seconds
# Time to solve scan 508/900: 0.12010407447814941 seconds
# Time to solve scan 509/900: 0.07332229614257812 seconds
# Time to solve scan 510/900: 0.07479739189147949 seconds
# Time to solve scan 511/900: 0.07776069641113281 seconds
# Time to solve scan 512/900: 0.07701444625854492 seconds
# Time to solve scan 513/900: 0.07730960845947266 seconds
# Time to solve scan 514/900: 0.0737922191619873 seconds
# Time to solve scan 515/900: 0.08886027336120605 seconds
# Time to solve scan 516/900: 0.06950211524963379 seconds
# Time to solve scan 517/900: 0.07574725151062012 seconds
# Time to solve scan 518/900: 0.07826471328735352 seconds
# Time to solve scan 519/900: 0.07579827308654785 seconds
# Time to solve scan 520/900: 0.07218599319458008 seconds
# Time to solve scan 521/900: 0.07868576049804688 seconds
# Time to solve scan 522/900: 0.08714103698730469 seconds
# Time to solve scan 523/900: 0.08783292770385742 seconds
# Time to solve scan 524/900: 0.12202787399291992 seconds
# Time to solve scan 525/900: 0.07808303833007812 seconds
# Time to solve scan 526/900: 0.06984543800354004 seconds
# Time to solve scan 527/900: 0.0735006332397461 seconds
# Time to solve scan 528/900: 0.0724942684173584 seconds
# Time to solve scan 529/900: 0.07306885719299316 seconds
# Time to solve scan 530/900: 0.0711667537689209 seconds
# Time to solve scan 531/900: 0.07132673263549805 seconds
# Time to solve scan 532/900: 0.07433605194091797 seconds
# Time to solve scan 533/900: 0.06754517555236816 seconds
# Time to solve scan 534/900: 0.08465933799743652 seconds
# Time to solve scan 535/900: 0.07869195938110352 seconds
# Time to solve scan 536/900: 0.0772244930267334 seconds
# Time to solve scan 537/900: 0.08613944053649902 seconds
# Time to solve scan 538/900: 0.08249211311340332 seconds
# Time to solve scan 539/900: 0.07544779777526855 seconds
# Time to solve scan 540/900: 0.11613297462463379 seconds
# Time to solve scan 541/900: 0.07618236541748047 seconds
# Time to solve scan 542/900: 0.07558584213256836 seconds
# Time to solve scan 543/900: 0.0745086669921875 seconds
# Time to solve scan 544/900: 0.09132099151611328 seconds
# Time to solve scan 545/900: 0.08326125144958496 seconds
# Time to solve scan 546/900: 0.09107184410095215 seconds
# Time to solve scan 547/900: 0.08333730697631836 seconds
# Time to solve scan 548/900: 0.09941458702087402 seconds
# Time to solve scan 549/900: 0.09169745445251465 seconds
# Time to solve scan 550/900: 0.08651852607727051 seconds
# Time to solve scan 551/900: 0.08620166778564453 seconds
# Time to solve scan 552/900: 0.09786105155944824 seconds
# Time to solve scan 553/900: 0.0912930965423584 seconds
# Time to solve scan 554/900: 0.09212613105773926 seconds
# Time to solve scan 555/900: 0.11301612854003906 seconds
# Time to solve scan 556/900: 0.13173198699951172 seconds
# Time to solve scan 557/900: 0.07804608345031738 seconds
# Time to solve scan 558/900: 0.09070134162902832 seconds
# Time to solve scan 559/900: 0.07855582237243652 seconds
# Time to solve scan 560/900: 0.08075237274169922 seconds
# Time to solve scan 561/900: 0.06986045837402344 seconds
# Time to solve scan 562/900: 0.09422922134399414 seconds
# Time to solve scan 563/900: 0.10495567321777344 seconds
# Time to solve scan 564/900: 0.08177661895751953 seconds
# Time to solve scan 565/900: 0.0805058479309082 seconds
# Time to solve scan 566/900: 0.0819087028503418 seconds
# Time to solve scan 567/900: 0.07763552665710449 seconds
# Time to solve scan 568/900: 0.08279037475585938 seconds
# Time to solve scan 569/900: 0.07824254035949707 seconds
# Time to solve scan 570/900: 0.07542204856872559 seconds
# Time to solve scan 571/900: 0.08473944664001465 seconds
# Time to solve scan 572/900: 0.10867905616760254 seconds
# Time to solve scan 573/900: 0.07645177841186523 seconds
# Time to solve scan 574/900: 0.0705564022064209 seconds
# Time to solve scan 575/900: 0.08120465278625488 seconds
# Time to solve scan 576/900: 0.07039785385131836 seconds
# Time to solve scan 577/900: 0.06998682022094727 seconds
# Time to solve scan 578/900: 0.07143998146057129 seconds
# Time to solve scan 579/900: 0.07191824913024902 seconds
# Time to solve scan 580/900: 0.07487940788269043 seconds
# Time to solve scan 581/900: 0.06968235969543457 seconds
# Time to solve scan 582/900: 0.07769083976745605 seconds
# Time to solve scan 583/900: 0.0754096508026123 seconds
# Time to solve scan 584/900: 0.06746077537536621 seconds
# Time to solve scan 585/900: 0.06258034706115723 seconds
# Time to solve scan 586/900: 0.06347036361694336 seconds
# Time to solve scan 587/900: 0.07574868202209473 seconds
# Time to solve scan 588/900: 0.0996253490447998 seconds
# Time to solve scan 589/900: 0.06559133529663086 seconds
# Time to solve scan 590/900: 0.07700371742248535 seconds
# Time to solve scan 591/900: 0.07284426689147949 seconds
# Time to solve scan 592/900: 0.07236313819885254 seconds
# Time to solve scan 593/900: 0.07886505126953125 seconds
# Time to solve scan 594/900: 0.0736081600189209 seconds
# Time to solve scan 595/900: 0.07517075538635254 seconds
# Time to solve scan 596/900: 0.07720208168029785 seconds
# Time to solve scan 597/900: 0.07289624214172363 seconds
# Time to solve scan 598/900: 0.07450246810913086 seconds
# Time to solve scan 599/900: 0.07357120513916016 seconds
# Time to solve scan 600/900: 0.07179474830627441 seconds
# Time to solve scan 601/900: 0.07603025436401367 seconds
# Time to solve scan 602/900: 0.07378959655761719 seconds
# Time to solve scan 603/900: 0.06702971458435059 seconds
# Time to solve scan 604/900: 0.11139440536499023 seconds
# Time to solve scan 605/900: 0.07421636581420898 seconds
# Time to solve scan 606/900: 0.06467819213867188 seconds
# Time to solve scan 607/900: 0.06386804580688477 seconds
# Time to solve scan 608/900: 0.06928539276123047 seconds
# Time to solve scan 609/900: 0.06569719314575195 seconds
# Time to solve scan 610/900: 0.0668342113494873 seconds
# Time to solve scan 611/900: 0.06647086143493652 seconds
# Time to solve scan 612/900: 0.06479573249816895 seconds
# Time to solve scan 613/900: 0.06506967544555664 seconds
# Time to solve scan 614/900: 0.06533098220825195 seconds
# Time to solve scan 615/900: 0.060991764068603516 seconds
# Time to solve scan 616/900: 0.06502842903137207 seconds
# Time to solve scan 617/900: 0.06983184814453125 seconds
# Time to solve scan 618/900: 0.0839076042175293 seconds
# Time to solve scan 619/900: 0.08437442779541016 seconds
# Time to solve scan 620/900: 0.12613368034362793 seconds
# Time to solve scan 621/900: 0.07644796371459961 seconds
# Time to solve scan 622/900: 0.09938383102416992 seconds
# Time to solve scan 623/900: 0.08734822273254395 seconds
# Time to solve scan 624/900: 0.0866091251373291 seconds
# Time to solve scan 625/900: 0.0726768970489502 seconds
# Time to solve scan 626/900: 0.07101869583129883 seconds
# Time to solve scan 627/900: 0.0810554027557373 seconds
# Time to solve scan 628/900: 0.0705263614654541 seconds
# Time to solve scan 629/900: 0.07091736793518066 seconds
# Time to solve scan 630/900: 0.08397364616394043 seconds
# Time to solve scan 631/900: 0.06781458854675293 seconds
# Time to solve scan 632/900: 0.07103252410888672 seconds
# Time to solve scan 633/900: 0.07019710540771484 seconds
# Time to solve scan 634/900: 0.07646846771240234 seconds
# Time to solve scan 635/900: 0.10041666030883789 seconds
# Time to solve scan 636/900: 0.06763052940368652 seconds
# Time to solve scan 637/900: 0.06322455406188965 seconds
# Time to solve scan 638/900: 0.062470197677612305 seconds
# Time to solve scan 639/900: 0.06502842903137207 seconds
# Time to solve scan 640/900: 0.0676107406616211 seconds
# Time to solve scan 641/900: 0.06500744819641113 seconds
# Time to solve scan 642/900: 0.06347250938415527 seconds
# Time to solve scan 643/900: 0.06570625305175781 seconds
# Time to solve scan 644/900: 0.07320404052734375 seconds
# Time to solve scan 645/900: 0.07290267944335938 seconds
# Time to solve scan 646/900: 0.0713038444519043 seconds
# Time to solve scan 647/900: 0.09874963760375977 seconds
# Time to solve scan 648/900: 0.07881617546081543 seconds
# Time to solve scan 649/900: 0.07652473449707031 seconds
# Time to solve scan 650/900: 0.06945347785949707 seconds
# Time to solve scan 651/900: 0.11117172241210938 seconds
# Time to solve scan 652/900: 0.06593918800354004 seconds
# Time to solve scan 653/900: 0.06821870803833008 seconds
# Time to solve scan 654/900: 0.06097698211669922 seconds
# Time to solve scan 655/900: 0.062354087829589844 seconds
# Time to solve scan 656/900: 0.07320737838745117 seconds
# Time to solve scan 657/900: 0.06306028366088867 seconds
# Time to solve scan 658/900: 0.06932187080383301 seconds
# Time to solve scan 659/900: 0.07047152519226074 seconds
# Time to solve scan 660/900: 0.07238602638244629 seconds
# Time to solve scan 661/900: 0.062270164489746094 seconds
# Time to solve scan 662/900: 0.06914877891540527 seconds
# Time to solve scan 663/900: 0.06603741645812988 seconds
# Time to solve scan 664/900: 0.06429529190063477 seconds
# Time to solve scan 665/900: 0.06835508346557617 seconds
# Time to solve scan 666/900: 0.06490159034729004 seconds
# Time to solve scan 667/900: 0.10606789588928223 seconds
# Time to solve scan 668/900: 0.0712733268737793 seconds
# Time to solve scan 669/900: 0.06211209297180176 seconds
# Time to solve scan 670/900: 0.06536388397216797 seconds
# Time to solve scan 671/900: 0.06710624694824219 seconds
# Time to solve scan 672/900: 0.06060647964477539 seconds
# Time to solve scan 673/900: 0.06981086730957031 seconds
# Time to solve scan 674/900: 0.06997323036193848 seconds
# Time to solve scan 675/900: 0.07127213478088379 seconds
# Time to solve scan 676/900: 0.0742335319519043 seconds
# Time to solve scan 677/900: 0.07143664360046387 seconds
# Time to solve scan 678/900: 0.07090878486633301 seconds
# Time to solve scan 679/900: 0.06722354888916016 seconds
# Time to solve scan 680/900: 0.0666499137878418 seconds
# Time to solve scan 681/900: 0.06984186172485352 seconds
# Time to solve scan 682/900: 0.10222840309143066 seconds
# Time to solve scan 683/900: 0.06797623634338379 seconds
# Time to solve scan 684/900: 0.06070756912231445 seconds
# Time to solve scan 685/900: 0.06555032730102539 seconds
# Time to solve scan 686/900: 0.06645059585571289 seconds
# Time to solve scan 687/900: 0.06313729286193848 seconds
# Time to solve scan 688/900: 0.06428337097167969 seconds
# Time to solve scan 689/900: 0.06625938415527344 seconds
# Time to solve scan 690/900: 0.0722801685333252 seconds
# Time to solve scan 691/900: 0.06475472450256348 seconds
# Time to solve scan 692/900: 0.06676268577575684 seconds
# Time to solve scan 693/900: 0.0635836124420166 seconds
# Time to solve scan 694/900: 0.06837129592895508 seconds
# Time to solve scan 695/900: 0.06764554977416992 seconds
# Time to solve scan 696/900: 0.06718778610229492 seconds
# Time to solve scan 697/900: 0.06848430633544922 seconds
# Time to solve scan 698/900: 0.10886836051940918 seconds
# Time to solve scan 699/900: 0.06849145889282227 seconds
# Time to solve scan 700/900: 0.06833744049072266 seconds
# Time to solve scan 701/900: 0.06707096099853516 seconds
# Time to solve scan 702/900: 0.06403374671936035 seconds
# Time to solve scan 703/900: 0.06543421745300293 seconds
# Time to solve scan 704/900: 0.06998324394226074 seconds
# Time to solve scan 705/900: 0.07126140594482422 seconds
# Time to solve scan 706/900: 0.07219195365905762 seconds
# Time to solve scan 707/900: 0.0687723159790039 seconds
# Time to solve scan 708/900: 0.0721273422241211 seconds
# Time to solve scan 709/900: 0.06948566436767578 seconds
# Time to solve scan 710/900: 0.06802248954772949 seconds
# Time to solve scan 711/900: 0.06644177436828613 seconds
# Time to solve scan 712/900: 0.07010340690612793 seconds
# Time to solve scan 713/900: 0.06720542907714844 seconds
# Time to solve scan 714/900: 0.10642004013061523 seconds
# Time to solve scan 715/900: 0.06975173950195312 seconds
# Time to solve scan 716/900: 0.06098127365112305 seconds
# Time to solve scan 717/900: 0.06651854515075684 seconds
# Time to solve scan 718/900: 0.06998944282531738 seconds
# Time to solve scan 719/900: 0.06932783126831055 seconds
# Time to solve scan 720/900: 0.06791281700134277 seconds
# Time to solve scan 721/900: 0.06821537017822266 seconds
# Time to solve scan 722/900: 0.06310772895812988 seconds
# Time to solve scan 723/900: 0.06475305557250977 seconds
# Time to solve scan 724/900: 0.06418585777282715 seconds
# Time to solve scan 725/900: 0.06761384010314941 seconds
# Time to solve scan 726/900: 0.06548142433166504 seconds
# Time to solve scan 727/900: 0.06749773025512695 seconds
# Time to solve scan 728/900: 0.06871223449707031 seconds
# Time to solve scan 729/900: 0.06200695037841797 seconds
# Time to solve scan 730/900: 0.06933355331420898 seconds
# Time to solve scan 731/900: 0.07175159454345703 seconds
# Time to solve scan 732/900: 0.10973167419433594 seconds
# Time to solve scan 733/900: 0.06816363334655762 seconds
# Time to solve scan 734/900: 0.06751513481140137 seconds
# Time to solve scan 735/900: 0.06996631622314453 seconds
# Time to solve scan 736/900: 0.07143521308898926 seconds
# Time to solve scan 737/900: 0.07959342002868652 seconds
# Time to solve scan 738/900: 0.06697440147399902 seconds
# Time to solve scan 739/900: 0.06797313690185547 seconds
# Time to solve scan 740/900: 0.0652778148651123 seconds
# Time to solve scan 741/900: 0.0664072036743164 seconds
# Time to solve scan 742/900: 0.06694626808166504 seconds
# Time to solve scan 743/900: 0.06374597549438477 seconds
# Time to solve scan 744/900: 0.0679175853729248 seconds
# Time to solve scan 745/900: 0.06417536735534668 seconds
# Time to solve scan 746/900: 0.0639963150024414 seconds
# Time to solve scan 747/900: 0.06418323516845703 seconds
# Time to solve scan 748/900: 0.06546282768249512 seconds
# Time to solve scan 749/900: 0.06400442123413086 seconds
# Time to solve scan 750/900: 0.11058616638183594 seconds
# Time to solve scan 751/900: 0.06522798538208008 seconds
# Time to solve scan 752/900: 0.07024884223937988 seconds
# Time to solve scan 753/900: 0.06549930572509766 seconds
# Time to solve scan 754/900: 0.06433486938476562 seconds
# Time to solve scan 755/900: 0.06825852394104004 seconds
# Time to solve scan 756/900: 0.06849360466003418 seconds
# Time to solve scan 757/900: 0.07358169555664062 seconds
# Time to solve scan 758/900: 0.06618285179138184 seconds
# Time to solve scan 759/900: 0.06766247749328613 seconds
# Time to solve scan 760/900: 0.06879305839538574 seconds
# Time to solve scan 761/900: 0.06739330291748047 seconds
# Time to solve scan 762/900: 0.07004451751708984 seconds
# Time to solve scan 763/900: 0.07276082038879395 seconds
# Time to solve scan 764/900: 0.0774695873260498 seconds
# Time to solve scan 765/900: 0.11225581169128418 seconds
# Time to solve scan 766/900: 0.07003498077392578 seconds
# Time to solve scan 767/900: 0.07974362373352051 seconds
# Time to solve scan 768/900: 0.0783693790435791 seconds
# Time to solve scan 769/900: 0.07297825813293457 seconds
# Time to solve scan 770/900: 0.06720137596130371 seconds
# Time to solve scan 771/900: 0.06770110130310059 seconds
# Time to solve scan 772/900: 0.07364034652709961 seconds
# Time to solve scan 773/900: 0.07042765617370605 seconds
# Time to solve scan 774/900: 0.08460021018981934 seconds
# Time to solve scan 775/900: 0.0679464340209961 seconds
# Time to solve scan 776/900: 0.06935262680053711 seconds
# Time to solve scan 777/900: 0.07247662544250488 seconds
# Time to solve scan 778/900: 0.08292174339294434 seconds
# Time to solve scan 779/900: 0.07248044013977051 seconds
# Time to solve scan 780/900: 0.11525344848632812 seconds
# Time to solve scan 781/900: 0.0732731819152832 seconds
# Time to solve scan 782/900: 0.06810474395751953 seconds
# Time to solve scan 783/900: 0.06976079940795898 seconds
# Time to solve scan 784/900: 0.06781697273254395 seconds
# Time to solve scan 785/900: 0.06558418273925781 seconds
# Time to solve scan 786/900: 0.07844376564025879 seconds
# Time to solve scan 787/900: 0.06891775131225586 seconds
# Time to solve scan 788/900: 0.07581949234008789 seconds
# Time to solve scan 789/900: 0.06907463073730469 seconds
# Time to solve scan 790/900: 0.06868791580200195 seconds
# Time to solve scan 791/900: 0.07128334045410156 seconds
# Time to solve scan 792/900: 0.07001852989196777 seconds
# Time to solve scan 793/900: 0.06643104553222656 seconds
# Time to solve scan 794/900: 0.06490325927734375 seconds
# Time to solve scan 795/900: 0.10644316673278809 seconds
# Time to solve scan 796/900: 0.08229827880859375 seconds
# Time to solve scan 797/900: 0.09426498413085938 seconds
# Time to solve scan 798/900: 0.07556939125061035 seconds
# Time to solve scan 799/900: 0.06926846504211426 seconds
# Time to solve scan 800/900: 0.07731795310974121 seconds
# Time to solve scan 801/900: 0.08150482177734375 seconds
# Time to solve scan 802/900: 0.07689404487609863 seconds
# Time to solve scan 803/900: 0.07204961776733398 seconds
# Time to solve scan 804/900: 0.07472062110900879 seconds
# Time to solve scan 805/900: 0.07268071174621582 seconds
# Time to solve scan 806/900: 0.0784003734588623 seconds
# Time to solve scan 807/900: 0.07991719245910645 seconds
# Time to solve scan 808/900: 0.07872343063354492 seconds
# Time to solve scan 809/900: 0.07215309143066406 seconds
# Time to solve scan 810/900: 0.13257336616516113 seconds
# Time to solve scan 811/900: 0.0893862247467041 seconds
# Time to solve scan 812/900: 0.08907389640808105 seconds
# Time to solve scan 813/900: 0.08878636360168457 seconds
# Time to solve scan 814/900: 0.09681868553161621 seconds
# Time to solve scan 815/900: 0.0851128101348877 seconds
# Time to solve scan 816/900: 0.087249755859375 seconds
# Time to solve scan 817/900: 0.07246279716491699 seconds
# Time to solve scan 818/900: 0.07540607452392578 seconds
# Time to solve scan 819/900: 0.07019686698913574 seconds
# Time to solve scan 820/900: 0.06728267669677734 seconds
# Time to solve scan 821/900: 0.05997490882873535 seconds
# Time to solve scan 822/900: 0.06552934646606445 seconds
# Time to solve scan 823/900: 0.07568359375 seconds
# Time to solve scan 824/900: 0.06998348236083984 seconds
# Time to solve scan 825/900: 0.11161923408508301 seconds
# Time to solve scan 826/900: 0.07232379913330078 seconds
# Time to solve scan 827/900: 0.07030582427978516 seconds
# Time to solve scan 828/900: 0.06616449356079102 seconds
# Time to solve scan 829/900: 0.0661771297454834 seconds
# Time to solve scan 830/900: 0.06720209121704102 seconds
# Time to solve scan 831/900: 0.06581640243530273 seconds
# Time to solve scan 832/900: 0.07273244857788086 seconds
# Time to solve scan 833/900: 0.07647371292114258 seconds
# Time to solve scan 834/900: 0.09669923782348633 seconds
# Time to solve scan 835/900: 0.08466815948486328 seconds
# Time to solve scan 836/900: 0.07780313491821289 seconds
# Time to solve scan 837/900: 0.08194112777709961 seconds
# Time to solve scan 838/900: 0.07439970970153809 seconds
# Time to solve scan 839/900: 0.07690715789794922 seconds
# Time to solve scan 840/900: 0.12255287170410156 seconds
# Time to solve scan 841/900: 0.07177329063415527 seconds
# Time to solve scan 842/900: 0.06937861442565918 seconds
# Time to solve scan 843/900: 0.0670013427734375 seconds
# Time to solve scan 844/900: 0.06605815887451172 seconds
# Time to solve scan 845/900: 0.0971827507019043 seconds
# Time to solve scan 846/900: 0.09034347534179688 seconds
# Time to solve scan 847/900: 0.07447218894958496 seconds
# Time to solve scan 848/900: 0.07491946220397949 seconds
# Time to solve scan 849/900: 0.0683600902557373 seconds
# Time to solve scan 850/900: 0.07199358940124512 seconds
# Time to solve scan 851/900: 0.07154393196105957 seconds
# Time to solve scan 852/900: 0.07423996925354004 seconds
# Time to solve scan 853/900: 0.06894636154174805 seconds
# Time to solve scan 854/900: 0.0668172836303711 seconds
# Time to solve scan 855/900: 0.10123825073242188 seconds
# Time to solve scan 856/900: 0.06641173362731934 seconds
# Time to solve scan 857/900: 0.06658577919006348 seconds
# Time to solve scan 858/900: 0.06951785087585449 seconds
# Time to solve scan 859/900: 0.07072758674621582 seconds
# Time to solve scan 860/900: 0.0739138126373291 seconds
# Time to solve scan 861/900: 0.06951332092285156 seconds
# Time to solve scan 862/900: 0.07725858688354492 seconds
# Time to solve scan 863/900: 0.06836414337158203 seconds
# Time to solve scan 864/900: 0.07302403450012207 seconds
# Time to solve scan 865/900: 0.07753229141235352 seconds
# Time to solve scan 866/900: 0.08054304122924805 seconds
# Time to solve scan 867/900: 0.07644796371459961 seconds
# Time to solve scan 868/900: 0.07471632957458496 seconds
# Time to solve scan 869/900: 0.0689091682434082 seconds
# Time to solve scan 870/900: 0.10330557823181152 seconds
# Time to solve scan 871/900: 0.06725144386291504 seconds
# Time to solve scan 872/900: 0.06642746925354004 seconds
# Time to solve scan 873/900: 0.06287312507629395 seconds
# Time to solve scan 874/900: 0.07081246376037598 seconds
# Time to solve scan 875/900: 0.07028055191040039 seconds
# Time to solve scan 876/900: 0.07252120971679688 seconds
# Time to solve scan 877/900: 0.07421875 seconds
# Time to solve scan 878/900: 0.07318854331970215 seconds
# Time to solve scan 879/900: 0.06953811645507812 seconds
# Time to solve scan 880/900: 0.0786447525024414 seconds
# Time to solve scan 881/900: 0.0656728744506836 seconds
# Time to solve scan 882/900: 0.07318258285522461 seconds
# Time to solve scan 883/900: 0.06460428237915039 seconds
# Time to solve scan 884/900: 0.06593632698059082 seconds
# Time to solve scan 885/900: 0.10681629180908203 seconds
# Time to solve scan 886/900: 0.0689384937286377 seconds
# Time to solve scan 887/900: 0.07195401191711426 seconds
# Time to solve scan 888/900: 0.07083868980407715 seconds
# Time to solve scan 889/900: 0.06449699401855469 seconds
# Time to solve scan 890/900: 0.0755763053894043 seconds
# Time to solve scan 891/900: 0.08057427406311035 seconds
# Time to solve scan 892/900: 0.07134556770324707 seconds
# Time to solve scan 893/900: 0.07305526733398438 seconds
# Time to solve scan 894/900: 0.08007693290710449 seconds
# Time to solve scan 895/900: 0.0734872817993164 seconds
# Time to solve scan 896/900: 0.06675243377685547 seconds
# Time to solve scan 897/900: 0.06853604316711426 seconds
# Time to solve scan 898/900: 0.06824898719787598 seconds
# Time to solve scan 899/900: 0.07240629196166992 seconds
# Time to solve scan 900/900: 0.11277031898498535 seconds

# %%
if nx <= 80 and ny <= 80 and propagation_slices <= 20:
    # Solve Full Space
    thin_sample = False
    full_system = False
    forward_model = ForwardModel(sample_space, thin_sample=thin_sample, 
                                 full_system_solver=full_system)

    # Iterative solution
    print("Solving iteratively for full sample...")
    solution_iterative_solve_full = forward_model.solve(verbose=True)

else:
    print("Skipping full space solution for large sample space dimensions (nx, ny > 50, nz > 20).")
# Out:
# Skipping full space solution for large sample space dimensions (nx, ny > 50, nz > 20).

# %% [markdown]
# ### 6. Solve in Reverse
#
# The exit wave of the forward solution can be set as the initial condition for
# the system to be solved in reverse.
#
# **To do:**
#  - fix this for full system.
#  - complete the test

# %%
# # Set Exit wave to initial condition for reverse
# print("Solving iteratively for thin sample in reverse...")
# initial_condition = solution_iterative_thin[..., -1].copy()  # Copy the last frame of the solution
# solution_iterative_thin_reverse = forward_model_iterative_thin.solve(reverse=True,
#                                                       initial_condition=initial_condition,
#                                                       verbose=True)

# import numpy as np
# # Compute RMSE between solution_iterative_solve_thin_reverse and itself
# rmse = np.sqrt(np.mean(np.abs(solution_iterative_thin[..., 0] - solution_iterative_thin_reverse[..., -1]) ** 2))
# print(f"RMSE between forward and backward solutions: {rmse}")

# %% [markdown]
# ### 8. Visualisation of Solutions
#
# Module to help view solutions.

# %%
# Plotting the solution for thin sample
if scan_points <= 12:
    visualisation.plot(solution=solution_iterative_thin)
visualisation.plot(solution=solution_iterative_thin, slider=True, probe_index=257)
# Out:
# interactive(children=(IntSlider(value=0, description='slice', max=19), Output()), _dom_classes=('widget-intera…

# %%
# Plot Solution for Full Sample Solves
if nx <= 80 and ny <= 80 and propagation_slices <= 20:
    visualisation.plot(solution=solution_iterative_solve_full)
    visualisation.plot(solution=solution_iterative_solve_full, slider=True, probe_index=0)
else:
    print("Skipping full space solution visualisation for large sample space dimensions (nx, ny > 50, nz > 20).")
# Out:
# Skipping full space solution visualisation for large sample space dimensions (nx, ny > 50, nz > 20).

# %% [markdown]
# ### 7. Save thin sample data to Tiff Files for Ptychography Reconstructions

# %%
import tifffile as tiff
import json
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

save_dir = Path("./results")
save_dir.mkdir(exist_ok=True)

# Save the data as a numpy file
exit_waves = solution_iterative_thin[:,:,:,-1]  # Get the exit waves from the solution
data = np.zeros_like(exit_waves, dtype=np.float32)

for frame_number in range(sample_space.num_probes):
    data[frame_number, :, :] = np.random.poisson(np.square(np.abs(np.fft.fftshift(np.fft.fft2(exit_waves[frame_number, :, :])))))
np.save(save_dir / 'data.npy', data)

# Save the object field cross section as a tif file
object_field_cross_section = sample_space.n_true[:, :, int(sample_space.nz / 2)]
object_field_cross_section = np.flipud(object_field_cross_section)
object_field_cross_section_modulus = np.abs(object_field_cross_section).astype(np.float32) 
object_field_cross_section_phase = np.angle(object_field_cross_section).astype(np.float32) 
tiff.imwrite(save_dir / 'object_field_cross_section_phase.tif', object_field_cross_section_phase)
object_field_cross_section = np.flipud(object_field_cross_section)
tiff.imwrite(save_dir / 'object_field_cross_section_modulus.tif', object_field_cross_section_modulus)

# Save the parameters as a json file
if bc_type == "dirichlet":
    probe_dimensions = [probe_dimensions[0]+2, probe_dimensions[1]+2]

parameters = {
    "detector_shape": probe_dimensions,
    "probe_diameter": probe_diameter,
    "scan_step_size": step_size,
    "scan_points_xy": scan_points
}

with open(save_dir / 'parameters.json', 'w') as json_file:
    json.dump(parameters, json_file)

# %%
def plot_data(data, scan_points_xy):
    fig_re, axes_re = plt.subplots(scan_points_xy, scan_points_xy, figsize=(15, 12), squeeze=False)

    num_probes = data.shape[0]  # Number of frames

    for idx in range(num_probes):
        row = idx // scan_points_xy
        if row % 2 == 0:  # Even row (left to right)
            col = idx % scan_points_xy
        else:  # Odd row (right to left)
            col = scan_points_xy - 1 - ( idx % scan_points_xy )

        im_r = axes_re[row, col].imshow(np.log(data[idx, :, :]), cmap='gray',origin='lower')
        axes_re[row, col].set_title(f'Scan {idx+1}')

    fig_re.suptitle('Data Frames: DFT of Exit Wave (Log Scale)', fontsize=16)
    plt.show()

def plot_single_frame(data, frame_number):
    """
    Plot a single frame of the data.
    
    Parameters:
    - data: numpy array containing the data
    - frame_number: index of the frame to plot
    """
    plt.figure(figsize=(8, 6))
    plt.imshow(np.log(data[frame_number, :, :]), cmap='gray', origin='lower')
    plt.title(f'DFT of Exit Wave (Log Scale). Scan {frame_number + 1}')
    plt.colorbar(label='Log Scale')
    plt.show()

# Example usage
if scan_points <= 12:
    plot_data(data, scan_points)  # Adjust scan_points_xy as needed
plot_single_frame(data, 256)
# Out:
# /tmp/ipykernel_124850/657074572.py:28: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(data[frame_number, :, :]), cmap='gray', origin='lower')
